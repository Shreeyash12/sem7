# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pylab
from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn import preprocessing

# %%
df = pd.read_csv('uber.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199999 non-null  float64
#  1   pickup_longitude   199999 non-null  float64
#  2   pickup_latitude    199999 non-null  float64
#  3   dropoff_longitude  199999 non-null  float64
#  4   dropoff_latitude   199999 non-null  float64
#  5   passenger_count    199999 non-null  int64
#  6   Distance           199999 non-null  float64
#  7   second             199999 non-null  int64
#  8   minute             199999 non-null  int64
#  9   hour               199999 non-null  int64
#  10  day                199999 non-null  int64
#  11  month              199999 non-null  int64
#  12  year               199999 non-null  int64
#  13  dayofweek          199999 non-null  int64
# dtypes: float64(6), int64(8)
# memory usage: 21.4 MB

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  Distance  second  minute  hour  day  \
# 0         40.723217                1  1.683323       6      52    19    7
# 1         40.750325                1  2.457590      56       4    20   17
# 2         40.772647                1  5.036377       0      45    21   24
# 3         40.803349                3  1.661683      21      22     8   26
# 4         40.761247                5  4.475450       0      47    17   28
#
#    month  year  dayofweek
# 0      5  2015          3
# 1      7  2009          4
# 2      8  2009          0
# 3      6  2009          4
# 4      8  2014          3

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199999.000000     199999.000000    199999.000000      199999.000000
# mean       11.359892        -72.527631        39.935881         -72.525292
# std         9.901760         11.437815         7.720558          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963659
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count       Distance         second  \
# count     199999.000000    199999.000000  199999.000000  199999.000000
# mean          39.923890         1.684543      20.855350      15.801609
# std            6.794829         1.385995     382.964642      19.430352
# min         -881.985513         0.000000       0.000000       0.000000
# 25%           40.733823         1.000000       1.215222       0.000000
# 50%           40.753042         1.000000       2.120992       3.000000
# 75%           40.768001         2.000000       3.875169      32.000000
# max          872.697628       208.000000   16409.239135      59.000000
#
#               minute           hour            day          month  \
# count  199999.000000  199999.000000  199999.000000  199999.000000
# mean       29.534848      13.491387      15.704739       6.281791
# std        17.335443       6.515505       8.687377       3.438933
# min         0.000000       0.000000       1.000000       1.000000
# 25%        14.000000       9.000000       8.000000       3.000000
# 50%        30.000000      14.000000      16.000000       6.000000
# 75%        45.000000      19.000000      23.000000       9.000000
# max        59.000000      23.000000      31.000000      12.000000
#
#                 year      dayofweek
# count  199999.000000  199999.000000
# mean     2011.742434       3.048435
# std         1.856400       1.946946
# min      2009.000000       0.000000
# 25%      2010.000000       1.000000
# 50%      2012.000000       3.000000
# 75%      2013.000000       5.000000
# max      2015.000000       6.000000

# %%
df.isna().sum()
# Out:
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# Distance             0
# second               0
# minute               0
# hour                 0
# day                  0
# month                0
# year                 0
# dayofweek            0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# Distance             float64
# second                 int64
# minute                 int64
# hour                   int64
# day                    int64
# month                  int64
# year                   int64
# dayofweek              int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199999 non-null  float64
#  1   pickup_longitude   199999 non-null  float64
#  2   pickup_latitude    199999 non-null  float64
#  3   dropoff_longitude  199999 non-null  float64
#  4   dropoff_latitude   199999 non-null  float64
#  5   passenger_count    199999 non-null  int64
#  6   Distance           199999 non-null  float64
#  7   second             199999 non-null  int64
#  8   minute             199999 non-null  int64
#  9   hour               199999 non-null  int64
#  10  day                199999 non-null  int64
#  11  month              199999 non-null  int64
#  12  year               199999 non-null  int64
#  13  dayofweek          199999 non-null  int64
# dtypes: float64(6), int64(8)
# memory usage: 21.4 MB

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  Distance  second  minute  hour  day  \
# 0         40.723217                1  1.683323       6      52    19    7
# 1         40.750325                1  2.457590      56       4    20   17
# 2         40.772647                1  5.036377       0      45    21   24
# 3         40.803349                3  1.661683      21      22     8   26
# 4         40.761247                5  4.475450       0      47    17   28
#
#    month  year  dayofweek
# 0      5  2015          3
# 1      7  2009          4
# 2      8  2009          0
# 3      6  2009          4
# 4      8  2014          3

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
plt.figure(figsize=(20,12))
sns.boxplot(data = df)
# Out:
# <AxesSubplot: >

# %%
df.drop(df[df['Distance'] >= 60].index, inplace = True)
df.drop(df[df['fare_amount'] <= 0].index, inplace = True)

df.drop(df[(df['fare_amount']>100) & (df['Distance']<1)].index, inplace = True )
df.drop(df[(df['fare_amount']<100) & (df['Distance']>100)].index, inplace = True )

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
corr = df.corr()

corr.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_4b60e_row0_col0, #T_4b60e_row1_col1, #T_4b60e_row1_col3, #T_4b60e_row2_col2, #T_4b60e_row3_col1, #T_4b60e_row3_col3, #T_4b60e_row4_col4, #T_4b60e_row5_col5, #T_4b60e_row6_col6, #T_4b60e_row7_col7, #T_4b60e_row8_col8, #T_4b60e_row9_col9, #T_4b60e_row10_col10, #T_4b60e_row11_col11, #T_4b60e_row12_col12, #T_4b60e_row13_col13 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_4b60e_row0_col1, #T_4b60e_row0_col3, #T_4b60e_row8_col1, #T_4b60e_row8_col3, #T_4b60e_row9_col1, #T_4b60e_row9_col3, #T_4b60e_row10_col1, #T_4b60e_row10_col3, #T_4b60e_row11_col4, #T_4b60e_row12_col1, #T_4b60e_row12_col3, #T_4b60e_row13_col1, #T_4b60e_row13_col3 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_4b60e_row0_col2, #T_4b60e_row8_col2, #T_4b60e_row10_col2, #T_4b60e_row10_col4, #T_4b60e_row12_col2, #T_4b60e_row12_col4, #T_4b60e_row13_col2 {
#   background-color: #6ac4a7;
#   color: #000000;
# }
# #T_4b60e_row0_col4, #T_4b60e_row5_col1, #T_4b60e_row5_col2, #T_4b60e_row5_col3, #T_4b60e_row5_col4, #T_4b60e_row8_col4, #T_4b60e_row9_col2, #T_4b60e_row9_col4, #T_4b60e_row11_col1, #T_4b60e_row11_col2, #T_4b60e_row11_col3, #T_4b60e_row13_col4 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_4b60e_row0_col5, #T_4b60e_row7_col12, #T_4b60e_row11_col5 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_4b60e_row0_col6 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_4b60e_row0_col7, #T_4b60e_row2_col5, #T_4b60e_row4_col5, #T_4b60e_row10_col7 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_4b60e_row0_col8, #T_4b60e_row1_col2, #T_4b60e_row1_col4, #T_4b60e_row1_col6, #T_4b60e_row3_col2, #T_4b60e_row3_col4, #T_4b60e_row3_col6, #T_4b60e_row4_col1, #T_4b60e_row4_col3, #T_4b60e_row5_col7, #T_4b60e_row6_col8, #T_4b60e_row7_col5, #T_4b60e_row9_col0, #T_4b60e_row9_col13, #T_4b60e_row11_col10, #T_4b60e_row11_col12, #T_4b60e_row12_col11, #T_4b60e_row13_col9 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_4b60e_row0_col9, #T_4b60e_row7_col11 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_4b60e_row0_col10, #T_4b60e_row6_col10, #T_4b60e_row7_col0, #T_4b60e_row8_col10 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_4b60e_row0_col11, #T_4b60e_row11_col7 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_4b60e_row0_col12 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_4b60e_row0_col13, #T_4b60e_row1_col13, #T_4b60e_row3_col13, #T_4b60e_row10_col9, #T_4b60e_row10_col11, #T_4b60e_row10_col13, #T_4b60e_row12_col13 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_4b60e_row1_col0, #T_4b60e_row1_col10, #T_4b60e_row3_col0, #T_4b60e_row3_col10, #T_4b60e_row5_col10, #T_4b60e_row9_col10, #T_4b60e_row10_col0, #T_4b60e_row13_col0, #T_4b60e_row13_col10 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_4b60e_row1_col5, #T_4b60e_row3_col5, #T_4b60e_row6_col7, #T_4b60e_row8_col5, #T_4b60e_row8_col7, #T_4b60e_row10_col5, #T_4b60e_row13_col7 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_4b60e_row1_col7, #T_4b60e_row3_col7, #T_4b60e_row9_col7 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_4b60e_row1_col8, #T_4b60e_row2_col1, #T_4b60e_row2_col3, #T_4b60e_row2_col8, #T_4b60e_row2_col10, #T_4b60e_row3_col8, #T_4b60e_row4_col8, #T_4b60e_row4_col10, #T_4b60e_row5_col8, #T_4b60e_row7_col8, #T_4b60e_row9_col8, #T_4b60e_row10_col8, #T_4b60e_row11_col8, #T_4b60e_row12_col8, #T_4b60e_row12_col10, #T_4b60e_row13_col8 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_4b60e_row1_col9, #T_4b60e_row2_col9, #T_4b60e_row3_col9, #T_4b60e_row4_col9, #T_4b60e_row7_col13, #T_4b60e_row8_col9, #T_4b60e_row12_col9 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_4b60e_row1_col11, #T_4b60e_row2_col12, #T_4b60e_row3_col11, #T_4b60e_row4_col12, #T_4b60e_row6_col13, #T_4b60e_row8_col6, #T_4b60e_row8_col12, #T_4b60e_row9_col11, #T_4b60e_row13_col11 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_4b60e_row1_col12, #T_4b60e_row2_col11, #T_4b60e_row3_col12, #T_4b60e_row4_col11, #T_4b60e_row5_col12, #T_4b60e_row7_col6, #T_4b60e_row8_col11, #T_4b60e_row9_col12, #T_4b60e_row10_col6, #T_4b60e_row13_col12 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_4b60e_row2_col0, #T_4b60e_row4_col0, #T_4b60e_row7_col10, #T_4b60e_row8_col0 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_4b60e_row2_col4, #T_4b60e_row4_col2 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_4b60e_row2_col6 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_4b60e_row2_col7, #T_4b60e_row4_col7, #T_4b60e_row9_col5 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_4b60e_row2_col13, #T_4b60e_row4_col13, #T_4b60e_row8_col13, #T_4b60e_row9_col6, #T_4b60e_row11_col9 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_4b60e_row4_col6 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_4b60e_row5_col0 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_4b60e_row5_col6, #T_4b60e_row5_col11, #T_4b60e_row5_col13, #T_4b60e_row6_col11, #T_4b60e_row11_col6 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_4b60e_row5_col9, #T_4b60e_row10_col12 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_4b60e_row6_col0 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_4b60e_row6_col1, #T_4b60e_row6_col3 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_4b60e_row6_col2, #T_4b60e_row6_col4 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_4b60e_row6_col5, #T_4b60e_row12_col5 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_4b60e_row6_col9 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_4b60e_row6_col12, #T_4b60e_row12_col6 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_4b60e_row7_col1, #T_4b60e_row7_col3 {
#   background-color: #6cc4a8;
#   color: #000000;
# }
# #T_4b60e_row7_col2 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_4b60e_row7_col4 {
#   background-color: #64c1a2;
#   color: #000000;
# }
# #T_4b60e_row7_col9, #T_4b60e_row11_col13 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_4b60e_row11_col0 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_4b60e_row12_col0 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_4b60e_row12_col7 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_4b60e_row13_col5 {
#   background-color: #d7f0ee;
#   color: #000000;
# }
# #T_4b60e_row13_col6 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# </style>
# <table id="T_4b60e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b60e_level0_col0" class="col_heading level0 col0" >fare_amount</th>
#       <th id="T_4b60e_level0_col1" class="col_heading level0 col1" >pickup_longitude</th>
#       <th id="T_4b60e_level0_col2" class="col_heading level0 col2" >pickup_latitude</th>
#       <th id="T_4b60e_level0_col3" class="col_heading level0 col3" >dropoff_longitude</th>
#       <th id="T_4b60e_level0_col4" class="col_heading level0 col4" >dropoff_latitude</th>
#       <th id="T_4b60e_level0_col5" class="col_heading level0 col5" >passenger_count</th>
#       <th id="T_4b60e_level0_col6" class="col_heading level0 col6" >Distance</th>
#       <th id="T_4b60e_level0_col7" class="col_heading level0 col7" >second</th>
#       <th id="T_4b60e_level0_col8" class="col_heading level0 col8" >minute</th>
#       <th id="T_4b60e_level0_col9" class="col_heading level0 col9" >hour</th>
#       <th id="T_4b60e_level0_col10" class="col_heading level0 col10" >day</th>
#       <th id="T_4b60e_level0_col11" class="col_heading level0 col11" >month</th>
#       <th id="T_4b60e_level0_col12" class="col_heading level0 col12" >year</th>
#       <th id="T_4b60e_level0_col13" class="col_heading level0 col13" >dayofweek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b60e_level0_row0" class="row_heading level0 row0" >fare_amount</th>
#       <td id="T_4b60e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4b60e_row0_col1" class="data row0 col1" >0.005885</td>
#       <td id="T_4b60e_row0_col2" class="data row0 col2" >-0.006253</td>
#       <td id="T_4b60e_row0_col3" class="data row0 col3" >0.005501</td>
#       <td id="T_4b60e_row0_col4" class="data row0 col4" >-0.00

# %%
X = df['Distance'].values.reshape(-1, 1)        #Independent Variable
y = df['fare_amount'].values.reshape(-1, 1)     #Dependent Variable

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
y_std = std.fit_transform(y)
print(y_std)

x_std = std.fit_transform(X)
print(x_std)
# Out:
# [[-0.39820843]
#  [-0.37738556]
#  [ 0.1640092 ]
#  ...
#  [ 2.03806797]
#  [ 0.3305922 ]
#  [ 0.28894645]]
# [[-0.43819769]
#  [-0.22258873]
#  [ 0.49552213]
#  ...
#  [ 2.67145829]
#  [ 0.07874908]
#  [ 0.60173174]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_std, y_std, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
l_reg = LinearRegression()
l_reg.fit(X_train, y_train)

print("Training set score: {:.2f}".format(l_reg.score(X_train, y_train)))
print("Test set score: {:.7f}".format(l_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.74
# Test set score: 0.7340468

# %%
y_pred = l_reg.predict(X_test)

result = pd.DataFrame()
result[['Actual']] = y_test
result[['Predicted']] = y_pred

result.sample(10)
# Out:
#          Actual  Predicted
# 36054 -0.398208  -0.293309
# 26447 -0.502323  -0.584901
# 22384 -0.668906  -0.613220
# 1506  -0.502323  -0.532737
# 32052  3.495669   3.234649
# 2060  -0.033808  -0.157132
# 19262 -0.710552  -0.494343
# 11568  0.018249   0.224405
# 13315 -0.762609  -0.585603
# 17791 -0.710552  -0.404239

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.26621298757938766
# Mean Absolute % Error: 1.983074763340713
# Mean Squared Error: 0.2705243510778547
# Root Mean Squared Error: 0.5201195546005309
# R Squared (R²): 0.8567653080822019

# %%
plt.subplot(2, 2, 1)
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.title("Fare vs Distance (Training Set)")
plt.ylabel("fare_amount")
plt.xlabel("Distance")

plt.subplot(2, 2, 2)
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.ylabel("fare_amount")
plt.xlabel("Distance")
plt.title("Fare vs Distance (Test Set)")

plt.tight_layout()
plt.show()

# %%
cols = ['Model', 'RMSE', 'R-Squared']

# create a empty dataframe of the colums
# columns: specifies the columns to be selected
result_tabulation = pd.DataFrame(columns = cols)

# compile the required information
linreg_metrics = pd.DataFrame([[
     "Linear Regresion model",
     np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
     np.sqrt(metrics.r2_score(y_test, y_pred))
]], columns = cols)

result_tabulation = pd.concat([result_tabulation, linreg_metrics], ignore_index=True)

result_tabulation
# Out:
#                     Model     RMSE  R-Squared
# 0  Linear Regresion model  0.52012   0.856765

# %%
rf_reg = RandomForestRegressor(n_estimators=100, random_state=10)

# fit the regressor with training dataset
rf_reg.fit(X_train, y_train)
# Out:
# /tmp/ipykernel_4027/2264728154.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_reg.fit(X_train, y_train)
# RandomForestRegressor(random_state=10)

# %%
# predict the values on test dataset using predict()
y_pred_RF = rf_reg.predict(X_test)

result = pd.DataFrame()
result[['Actual']] = y_test
result['Predicted'] = y_pred_RF

result.sample(10)
# Out:
#          Actual  Predicted
# 22675  0.663758   1.273858
# 33906  3.141680   2.983114
# 24970 -0.294094  -0.268690
# 2130  -0.502323  -0.474732
# 37173 -0.398208  -0.561876
# 14912  1.371736   0.793422
# 22183  4.026653  -0.232146
# 30824 -0.710552  -0.628405
# 13657 -0.627260  -0.557483
# 19036  1.205153   0.749965

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_RF))
print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred_RF))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_RF))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_RF)))
print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred_RF)))
# Out:
# Mean Absolute Error: 0.3077087698385678
# Mean Absolute % Error: 2.161623761570947
# Mean Squared Error: 0.33297733033643484
# Root Mean Squared Error: 0.5770418791876677
# R Squared (R²): 0.8201518783882692

# %%
# Build scatterplot
plt.scatter(X_test, y_test, c = 'b', alpha = 0.5, marker = '.', label = 'Real')
plt.scatter(X_test, y_pred_RF, c = 'r', alpha = 0.5, marker = '.', label = 'Predicted')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.grid(color = '#D3D3D3', linestyle = 'solid')
plt.legend(loc = 'lower right')


plt.tight_layout()
plt.show()

# %%
# compile the required information
random_forest_metrics = pd.DataFrame([[
     "Random Forest Regressor model",
     np.sqrt(metrics.mean_squared_error(y_test, y_pred_RF)),
     np.sqrt(metrics.r2_score(y_test, y_pred_RF))
]], columns = cols)

result_tabulation = pd.concat([result_tabulation, random_forest_metrics], ignore_index=True)

result_tabulation
# Out:
#                            Model      RMSE  R-Squared
# 0         Linear Regresion model  0.520120   0.856765
# 1  Random Forest Regressor model  0.577042   0.820152
